# %% [markdown]
# <a href="https://colab.research.google.com/github/Halibo01/project_collaboration/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/birads_classification_training.zip
# Out:
# Archive:  /content/drive/MyDrive/birads_classification_training.zip
#    creating: birads_classification_training/test/
#    creating: birads_classification_training/test/birads_1/
#   inflating: birads_classification_training/test/birads_1/10922.png
#   inflating: birads_classification_training/test/birads_1/10923.png
#   inflating: birads_classification_training/test/birads_1/10924.png
#   inflating: birads_classification_training/test/birads_1/10925.png
#   inflating: birads_classification_training/test/birads_1/10927.png
#   inflating: birads_classification_training/test/birads_1/10928.png
#   inflating: birads_classification_training/test/birads_1/10929.png
#   inflating: birads_classification_training/test/birads_1/10930.png
#   inflating: birads_classification_training/test/birads_1/10931.png
#   inflating: birads_classification_training/test/birads_1/10932.png
#   inflating: birads_classification_training/test/birads_1/10933.png
#   inflating: birads_classification_training/test/birads_1/10934.png
#   inflating: birads_classification_training/test/birads_1/10935.png
#   inflating: birads_classification_training/test/birads_1/10936.png
#   inflating: birads_classification_training/test/birads_1/10937.png
#   inflating: birads_classification_training/test/birads_1/10938.png
#   inflating: birads_classification_training/test/birads_1/10939.png
#   inflating: birads_classification_training/test/birads_1/10940.png
#   inflating: birads_classification_training/test/birads_1/10941.png
#   inflating: birads_classification_training/test/birads_1/10942.png
#   inflating: birads_classification_training/test/birads_1/10943.png
#   inflating: birads_classification_training/test/birads_1/10944.png
#   inflating: birads_classification_training/test/birads_1/10945.png
#   inflating: birads_classification_training/test/birads_1/10946.png
#   inflating: birads_classification_training/test/birads_1/10947.png
#   inflating: birads_classification_training/test/birads_1/10948.png
#   inflating: birads_classification_training/test/birads_1/10949.png
#   inflating: birads_classification_training/test/birads_1/10950.png
#   inflating: birads_classification_training/test/birads_1/10951.png
#   inflating: birads_classification_training/test/birads_1/10952.png
#   inflating: birads_classification_training/test/birads_1/10953.png
#   inflating: birads_classification_training/test/birads_1/10954.png
#   inflating: birads_classification_training/test/birads_1/10955.png
#   inflating: birads_classification_training/test/birads_1/10956.png
#   inflating: birads_classification_training/test/birads_1/10957.png
#   inflating: birads_classification_training/test/birads_1/10958.png
#   inflating: birads_classification_training/test/birads_1/10959.png
#   inflating: birads_classification_training/test/birads_1/10960.png
#   inflating: birads_classification_training/test/birads_1/10962.png
#   inflating: birads_classification_training/test/birads_1/10963.png
#   inflating: birads_classification_training/test/birads_1/10964.png
#   inflating: birads_classification_training/test/birads_1/10965.png
#   inflating: birads_classification_training/test/birads_1/10966.png
#   inflating: birads_classification_training/test/birads_1/10967.png
#   inflating: birads_classification_training/test/birads_1/10968.png
#   inflating: birads_classification_training/test/birads_1/10969.png
#   inflating: birads_classification_training/test/birads_1/10970.png
#   inflating: birads_classification_training/test/birads_1/10971.png
#   inflating: birads_classification_training/test/birads_1/10972.png
#   inflating: birads_classification_training/test/birads_1/10973.png
#   inflating: birads_classification_training/test/birads_1/10974.png
#   inflating: birads_classification_training/test/birads_1/10975.png
#   inflating: birads_classification_training/test/birads_1/10976.png
#   inflating: birads_classification_training/test/birads_1/10977.png
#   inflating: birads_classification_training/test/birads_1/10978.png
#   inflating: birads_classification_training/test/birads_1/10979.png
#   inflating: birads_classification_training/test/birads_1/10980.png
#   inflating: birads_classification_training/test/birads_1/10981.png
#   inflating: birads_classification_training/test/birads_1/10982.png
#   inflating: birads_classification_training/test/birads_1/10983.png
#   inflating: birads_classification_training/test/birads_1/10984.png
#   inflating: birads_classification_training/test/birads_1/10985.png
#   inflating: birads_classification_training/test/birads_1/10986.png
#   inflating: birads_classification_training/test/birads_1/10987.png
#   inflating: birads_classification_training/test/birads_1/10988.png
#   inflating: birads_classification_training/test/birads_1/10989.png
#   inflating: birads_classification_training/test/birads_1/10990.png
#   inflating: birads_classification_training/test/birads_1/10991.png
#   inflating: birads_classification_training/test/birads_1/10992.png
#   inflating: birads_classification_training/test/birads_1/10993.png
#   inflating: birads_classification_training/test/birads_1/10994.png
#   inflating: birads_classification_training/test/birads_1/10996.png
#   inflating: birads_classification_training/test/birads_1/10997.png
#   inflating: birads_classification_training/test/birads_1/10998.png
#   inflating: birads_classification_training/test/birads_1/10999.png
#   inflating: birads_classification_training/test/birads_1/11000.png
#   inflating: birads_classification_training/test/birads_1/11001.png
#   inflating: birads_classification_training/test/birads_1/11002.png
#   inflating: birads_classification_training/test/birads_1/11003.png
#   inflating: birads_classification_training/test/birads_1/11004.png
#   inflating: birads_classification_training/test/birads_1/11005.png
#   inflating: birads_classification_training/test/birads_1/11006.png
#   inflating: birads_classification_training/test/birads_1/11007.png
#   inflating: birads_classification_training/test/birads_1/11008.png
#   inflating: birads_classification_training/test/birads_1/11009.png
#   inflating: birads_classification_training/test/birads_1/11010.png
#   inflating: birads_classification_training/test/birads_1/11011.png
#   inflating: birads_classification_training/test/birads_1/11012.png
#   inflating: birads_classification_training/test/birads_1/11013.png
#   inflating: birads_classification_training/test/birads_1/11014.png
#   inflating: birads_classification_training/test/birads_1/11015.png
#   inflating: birads_classification_training/test/birads_1/11016.png
#   inflating: birads_classification_training/test/birads_1/11017.png
#   inflating: birads_classification_training/test/birads_1/11018.png
#   inflating: birads_classification_training/test/birads_1/11019.png
#   inflating: birads_classification_training/test/birads_1/11020.png
#   inflating: birads_classification_training/test/birads_1/11021.png
#   inflating: birads_classification_training/test/birads_1/11022.png
#   inflating: birads_classification_training/test/birads_1/11023.png
#   inflating: birads_classification_training/test/birads_1/11024.png
#    creating: birads_classification_training/test/birads_2/
#   inflating: birads_classification_training/test/birads_2/11576.png
#   inflating: birads_classification_training/test/birads_2/11577.png
#   inflating: birads_classification_training/test/birads_2/11579.png
#   inflating: birads_classification_training/test/birads_2/11580.png
#   inflating: birads_classification_training/test/birads_2/11581.png
#   inflating: birads_classification_training/test/birads_2/11582.png
#   inflating: birads_classification_training/test/birads_2/11583.png
#   inflating: birads_classification_training/test/birads_2/11584.png
#   inflating: birads_classification_training/test/birads_2/11585.png
#   inflating: birads_classification_training/test/birads_2/11586.png
#   inflating: birads_classification_training/test/birads_2/11587.png
#   inflating: birads_classification_training/test/birads_2/11588.png
#   inflating: birads_classification_training/test/birads_2/11589.png
#   inflating: birads_classification_training/test/birads_2/11590.png
#   inflating: birads_classification_training/test/birads_2/11591.png
#   inflating: birads_classification_training/test/birads_2/11592.png
#   inflating: birads_classification_training/test/birads_2/11593.png
#   inflating: birads_classification_training/test/birads_2/11594.png
#   inflating: birads_classification_training/test/birads_2/11595.png
#   inflating: birads_classification_training/test/birads_2/11596.png
#   inflating: birads_classification_training/test/birads_2/11597.png
#   inflating: birads_classification_training/test/birads_2/11598.png
#   inflating: birads_classification_training/test/birads_2/11599.png
#   inflating: birads_classification_training/test/birads_2/11600.png
#   inflating: birads_classification_training/test/birads_2/11601.png
#   inflating: birads_classification_training/test/birads_2/11602.png
#   inflating: birads_classification_training/test/birads_2/11603.png
#   inflating: birads_classification_training/test/birads_2/11604.png
#   inflating: birads_classification_training/test/birads_2/11605.png
#   inflating: birads_classification_training/test/birads_2/11606.png
#   inflating: birads_classification_training/test/birads_2/11607.png
#   inflating: birads_classification_training/test/birads_2/11608.png
#   inflating: birads_classification_training/test/birads_2/11609.png
#   inflating: birads_classification_training/test/birads_2/11610.png
#   inflating: birads_classification_training/test/birads_2/11611.png
#   inflating: birads_classification_training/test/birads_2/11612.png
#   inflating: birads_classification_training/test/birads_2/11613.png
#   inflating: birads_classification_training/test/birads_2/11614.png
#   inflating: birads_classification_training/test/birads_2/11615.png
#   inflating: birads_classification_training/test/birads_2/11616.png
#   inflating: birads_classification_training/test/birads_2/11617.png
#   inflating: birads_classification_training/test/birads_2/11618.png
#   inflating: birads_classification_training/test/birads_2/11619.png
#   inflating: birads_classification_training/test/birads_2/11620.png
#   inflating: birads_classification_training/test/birads_2/11621.png
#   inflating: birads_classification_training/test/birads_2/11622.png
#   inflating: birads_classification_training/test/birads_2/11623.png
#   inflating: birads_classification_training/test/birads_2/11624.png
#   inflating: birads_classification_training/test/birads_2/11625.png
#   inflating: birads_classification_training/test/birads_2/11626.png
#   inflating: birads_classification_training/test/birads_2/11627.png
#   inflating: birads_classification_training/test/birads_2/11628.png
#   inflating: birads_classification_training/test/birads_2/11629.png
#   inflating: birads_classification_training/test/birads_2/11630.png
#   inflating: birads_classification_training/test/birads_2/11631.png
#   inflating: birads_classification_training/test/birads_2/11632.png
#   inflating: birads_classification_training/test/birads_2/11633.png
#   inflating: birads_classification_training/test/birads_2/11634.png
#   inflating: birads_classification_training/test/birads_2/11635.png
#    creating: birads_classification_training/test/birads_4/
#   inflating: birads_classification_training/test/birads_4/12113.png
#   inflating: birads_classification_training/test/birads_4/12114.png
#   inflating: birads_classification_training/test/birads_4/12115.png
#   inflating: birads_classification_training/test/birads_4/12116.png
#   inflating: birads_classification_training/test/birads_4/12117.png
#   inflating: birads_classification_training/test/birads_4/12118.png
#   inflating: birads_classification_training/test/birads_4/12119.png
#   inflating: birads_classification_training/test/birads_4/12120.png
#   inflating: birads_classification_training/test/birads_4/12121.png
#   inflating: birads_classification_training/test/birads_4/12122.png
#   inflating: birads_classification_training/test/birads_4/12123.png
#   inflating: birads_classification_training/test/birads_4/12124.png
#   inflating: birads_classification_training/test/birads_4/12125.png
#   inflating: birads_classification_training/test/birads_4/12126.png
#   inflating: birads_classification_training/test/birads_4/12127.png
#   inflating: birads_classification_training/test/birads_4/12128.png
#   inflating: birads_classification_training/test/birads_4/12129.png
#   inflating: birads_classification_training/test/birads_4/12130.png
#   inflating: birads_classification_training/test/birads_4/12131.png
#   inflating: birads_classification_training/test/birads_4/12132.png
#   inflating: birads_classification_training/test/birads_4/12133.png
#   inflating: birads_classification_training/test/birads_4/12134.png
#   inflating: birads_classification_training/test/birads_4/12135.png
#   inflating: birads_classification_training/test/birads_4/12137.png
#   inflating: birads_classification_training/test/birads_4/12138.png
#   inflating: birads_classification_training/test/birads_4/12139.png
#   inflating: birads_classification_training/test/birads_4/12140.png
#   inflating: birads_classification_training/test/birads_4/12141.png
#   inflating: birads_classification_training/test/birads_4/12142.png
#   inflating: birads_classification_training/test/birads_4/12143.png
#   inflating: birads_classification_training/test/birads_4/12144.png
#   inflating: birads_classification_training/test/birads_4/12145.png
#   inflating: birads_classification_training/test/birads_4/12146.png
#   inflating: birads_classification_training/test/birads_4/12147.png
#   inflating: birads_classification_training/test/birads_4/12148.png
#   inflating: birads_classification_training/test/birads_4/12149.png
#   inflating: birads_classification_training/test/birads_4/12151.png
#   inflating: birads_classification_training/test/birads_4/12152.png
#   inflating: birads_classification_training/test/birads_4/12153.png
#   inflating: birads_classification_training/test/birads_4/12154.png
#   inflating: birads_classification_training/test/birads_4/12155.png
#   inflating: birads_classification_training/test/birads_4/12156.png
#   inflating: birads_classification_training/test/birads_4/12157.png
#   inflating: birads_classification_training/test/birads_4/12158.png
#   inflating: birads_classification_training/test/birads_4/12159.png
#   inflating: birads_classification_training/test/birads_4/12160.png
#   inflating: birads_classification_training/test/birads_4/12161.png
#   inflating: birads_classification_training/test/birads_4/12162.png
#   inflating: birads_classification_training/test/birads_4/12163.png
#   inflating: birads_classification_training/test/birads_4/12164.png
#   inflating: birads_classification_training/test/birads_4/12165.png
#   inflating: birads_classification_training/test/birads_4/12166.png
#    creating: birads_classification_training/test/birads_5/
#   inflating: birads_classification_training/test/birads_5/12668.png
#   inflating: birads_classification_training/test/birads_5/12669.png
#   inflating: birads_classification_training/test/birads_5/12670.png
#   inflating: birads_classification_training/test/birads_5/12671.png
#   inflating: birads_classification_training/test/birads_5/12672.png
#   inflating: birads_classification_training/test/birads_5/12673.png
#   inflating: birads_classification_training/test/birads_5/12674.png
#   inflating: birads_classification_training/test/birads_5/12675.png
#   inflating: birads_classification_training/test/birads_5/12676.png
#   inflating: birads_classification_training/test/birads_5/12677.png
#   inflating: birads_classification_training/test/birads_5/12678.png
#   inflating: birads_classification_training/test/birads_5/12679.png
#   inflating: birads_classification_training/test/birads_5/12680.png
#   inflating: birads_classification_training/test/birads_5/12681.png
#   inflating: birads_classification_training/test/birads_5/12682.png
#   inflating: birads_classification_training/test/birads_5/12683.png
#   inflating: birads_classification_training/test/birads_5/12684.png
#   inflating: birads_classification_training/test/birads_5/12685.png
#   inflating: birads_classification_training/test/birads_5/12686.png
#   inflating: birads_classification_training/test/birads_5/12687.png
#   inflating: birads_classification_training/test/birads_5/12688.png
#   inflating: birads_classification_training/test/birads_5/12689.png
#   inflating: birads_classification_training/test/birads_5/12690.png
#   inflating: birads_classification_training/test/birads_5/12691.png
#   inflating: birads_classification_training/test/birads_5/12692.png
#   inflating: birads_classification_training/test/birads_5/12693.png
#   inflating: birads_classification_training/test/birads_5/12694.png
#   inflating: birads_classification_training/test/birads_5/12695.png
#   inflating: birads_classification_training/test/birads_5/12696.png
#   inflating: birads_classification_training/test/birads_5/12697.png
#   inflating: birads_classification_training/test/birads_5/12698.png
#   inflating: birads_classification_training/test/birads_5/12699.png
#   inflating: birads_classification_training/test/birads_5/12700.png
#   inflating: birads_classification_training/test/birads_5/12701.png
#   inflating: birads_classification_training/test/birads_5/12702.png
#   inflating: birads_classification_training/test/birads_5/12703.png
#   inflating: birads_classification_training/test/birads_5/12704.png
#   inflating: birads_classification_training/test/birads_5/12705.png
#   inflating: birads_classification_training/test/birads_5/12706.png
#   inflating: birads_classification_training/test/birads_5/12707.png
#   inflating: birads_classification_training/test/birads_5/12708.png
#   inflating: birads_classification_training/test/birads_5/12709.png
#   inflating: birads_classification_training/test/birads_5/12710.png
#   inflating: birads_classification_training/test/birads_5/12711.png
#   inflating: birads_classification_training/test/birads_5/12712.png
#   inflating: birads_classification_training/test/birads_5/12713.png
#   inflating: birads_classification_training/test/birads_5/12714.png
#   inflating: birads_classification_training/test/birads_5/12715.png
#   inflating: birads_classification_training/test/birads_5/12716.png
#   inflating: birads_classification_training/test/birads_5/12717.png
#   inflating: birads_classification_training/test/birads_5/12718.png
#   inflating: birads_classification_training/test/birads_5/12719.png
#   inflating: birads_classification_training/test/birads_5/12720.png
#   inflating: birads_classification_training/test/birads_5/12721.png
#    creating: birads_classification_training/train/
#    creating: birads_classification_training/train/birads_1/
#   inflating: birads_classification_training/train/birads_1/10001.png
#   inflating: birads_classification_training/train/birads_1/10002.png
#   inflating: birads_classification_training/train/birads_1/10003.png
#   inflating: birads_classification_training/train/birads_1/10004.png
#   inflating: birads_classification_training/train/birads_1/10005.png
#   inflating: birads_classification_training/train/birads_1/10006.png
#   inflating: birads_classification_training/train/birads_1/10007.png
#   inflating: birads_classification_training/train/birads_1/10008.png
#   inflating: birads_classification_training/train/birads_1/10009.png
#   inflating: birads_classification_training/train/birads_1/10010.png
#   inflating: birads_classification_training/train/birads_1/10011.png
#   inflating: birads_classification_training/train/birads_1/10012.png
#   inflating: birads_classification_training/train/birads_1/10013.png
#   inflating: birads_classification_training/train/birads_1/10014.png
#   inflating: birads_classification_training/train/birads_1/10015.png
#   inflating: birads_classification_training/train/birads_1/10016.png
#   inflating: birads_classification_training/train/birads_1/10017.png
#   inflating: birads_classification_training/train/birads_1/10018.png
#   inflating: birads_classification_training/train/birads_1/10019.png
#   inflating: birads_classification_training/train/birads_1/10020.png
#   inflating: birads_classification_training/train/birads_1/10021.png
#   inflating: birads_classification_training/train/birads_1/10022.png
#   inflating: birads_classification_training/train/birads_1/10023.png
#   inflating: birads_classification_training/train/birads_1/10024.png
#   inflating: birads_classification_training/train/birads_1/10025.png
#   inflating: birads_classification_training/train/birads_1/10026.png
#   inflating: birads_classification_training/train/birads_1/10027.png
#   inflating: birads_classification_training/train/birads_1/10028.png
#   inflating: birads_classification_training/train/birads_1/10029.png
#   inflating: birads_classification_training/train/birads_1/10030.png
#   inflating: birads_classification_training/train/birads_1/10031.png
#   inflating: birads_classification_training/train/birads_1/10032.png
#   inflating: birads_classification_training/train/birads_1/10033.png
#   inflating: birads_classification_training/train/birads_1/10034.png
#   inflating: birads_classification_training/train/birads_1/10035.png
#   inflating: birads_classification_training/train/birads_1/10037.png
#   inflating: birads_classification_training/train/birads_1/10038.png
#   inflating: birads_classification_training/train/birads_1/10039.png
#   inflating: birads_classification_training/train/birads_1/10040.png
#   inflating: birads_classification_training/train/birads_1/10041.png
#   inflating: birads_classification_training/train/birads_1/10042.png
#   inflating: birads_classification_training/train/birads_1/10043.png
#   inflating: birads_classification_training/train/birads_1/10044.png
#   inflating: birads_classification_training/train/birads_1/10045.png
#   inflating: birads_classification_training/train/birads_1/10046.png
#   inflating: birads_classification_training/train/birads_1/10047.png
#   inflating: birads_classification_training/train/birads_1/10048.png
#   inflating: birads_classification_training/train/birads_1/10049.png
#   inflating: birads_classification_training/train/birads_1/10050.png
#   inflating: birads_classification_training/train/birads_1/10051.png
#   inflating: birads_classification_training/train/birads_1/10052.png
#   inflating: birads_classification_training/train/birads_1/10053.png
#   inflating: birads_classification_training/train/birads_1/10054.png
#   inflating: birads_classification_training/train/birads_1/10055.png
#   inflating: birads_classification_training/train/birads_1/10056.png
#   inflating: birads_classification_training/train/birads_1/10057.png
#   inflating: birads_classification_training/train/birads_1/10058.png
#   inflating: birads_classification_training/train/birads_1/10059.png
#   inflating: birads_classification_training/train/birads_1/10061.png
#   inflating: birads_classification_training/train/birads_1/10062.png
#   inflating: birads_classification_training/train/birads_1/10063.png
#   inflating: birads_classification_training/train/birads_1/10064.png
#   inflating: birads_classification_training/train/birads_1/10065.png
#   inflating: birads_classification_training/train/birads_1/10066.png
#   inflating: birads_classification_training/train/birads_1/10067.png
#   inflating: birads_classification_training/train/birads_1/10068.png
#   inflating: birads_classification_training/train/birads_1/10069.png
#   inflating: birads_classification_training/train/birads_1/10070.png
#   inflating: birads_classification_training/train/birads_1/10071.png
#   inflating: birads_classification_training/train/birads_1/10072.png
#   inflating: birads_classification_training/train/birads_1/10073.png
#   inflating: birads_classification_training/train/birads_1/10074.png
#   inflating: birads_classification_training/train/birads_1/10075.png
#   inflating: birads_classification_training/train/birads_1/10077.png
#   inflating: birads_classification_training/train/birads_1/10078.png
#   inflating: birads_classification_training/train/birads_1/10079.png
#   inflating: birads_classification_training/train/birads_1/10080.png
#   inflating: birads_classification_training/train/birads_1/10081.png
#   inflating: birads_classification_training/train/birads_1/10082.png
#   inflating: birads_classification_training/train/birads_1/10083.png
#   inflating: birads_classification_training/train/birads_1/10084.png
#   inflating: birads_classification_training/train/birads_1/10085.png
#   inflating: birads_classification_training/train/birads_1/10086.png
#   inflating: birads_classification_training/train/birads_1/10087.png
#   inflating: birads_classification_training/train/birads_1/10088.png
#   inflating: birads_classification_training/train/birads_1/10089.png
#   inflating: birads_classification_training/train/birads_1/10090.png
#   inflating: birads_classification_training/train/birads_1/10091.png
#   inflating: birads_classification_training/train/birads_1/10092.png
#   inflating: birads_classification_training/train/birads_1/10093.png
#   inflating: birads_classification_training/train/birads_1/10094.png
#   inflating: birads_classification_training/train/birads_1/10095.png
#   inflating: birads_classification_training/train/birads_1/10096.png
#   inflating: birads_classification_training/train/birads_1/10097.png
#   inflating: birads_classification_training/train/birads_1/10098.png
#   inflating: birads_classification_training/train/birads_1/10099.png
#   inflating: birads_classification_training/train/birads_1/10100.png
#   inflating: birads_classification_training/train/birads_1/10101.png
#   inflating: birads_classification_training/train/birads_1/10102.png
#   inflating: birads_classification_training/train/birads_1/10103.png
#   inflating: birads_classification_training/train/birads_1/10104.png
#   inflating: birads_classification_training/train/birads_1/10105.png
#   inflating: birads_classification_training/train/birads_1/10106.png
#   inflating: birads_classification_training/train/birads_1/10107.png
#   inflating: birads_classification_training/train/birads_1/10108.png
#   inflating: birads_classification_training/train/birads_1/10109.png
#   inflating: birads_classification_training/train/birads_1/10110.png
#   inflating: birads_classification_training/train/birads_1/10111.png
#   inflating: birads_classification_training/train/birads_1/10112.png
#   inflating: birads_classification_training/train/birads_1/10113.png
#   inflating: birads_classification_training/train/birads_1/10114.png
#   inflating: birads_classification_training/train/birads_1/10115.png
#   inflating: birads_classification_training/train/birads_1/10116.png
#   inflating: birads_classification_training/train/birads_1/10117.png
#   inflating: birads_classification_training/train/birads_1/10118.png
#   inflating: birads_classification_training/train/birads_1/10119.png
#   inflating: birads_classification_training/train/birads_1/10120.png
#   inflating: birads_classification_training/train/birads_1/10121.png
#   inflating: birads_classification_training/train/birads_1/10122.png
#   inflating: birads_classification_training/train/birads_1/10123.png
#   inflating: birads_classification_training/train/birads_1/10124.png
#   inflating: birads_classification_training/train/birads_1/10125.png
#   inflating: birads_classification_training/train/birads_1/10126.png
#   inflating: birads_classification_training/train/birads_1/10127.png
#   inflating: birads_classification_training/train/birads_1/10128.png
#   inflating: birads_classification_training/train/birads_1/10129.png
#   inflating: birads_classification_training/train/birads_1/10130.png
#   inflating: birads_classification_training/train/birads_1/10131.png
#   inflating: birads_classification_training/train/birads_1/10132.png
#   inflating: birads_classification_training/train/birads_1/10133.png
#   inflating: birads_classification_training/train/birads_1/10134.png
#   inflating: birads_classification_training/train/birads_1/10135.png
#   inflating: birads_classification_training/train/birads_1/10136.png
#   inflating: birads_classification_training/train/birads_1/10137.png
#   inflating: birads_classification_training/train/birads_1/10138.png
#   inflating: birads_classification_training/train/birads_1/10139.png
#   inflating: birads_classification_training/train/birads_1/10140.png
#   inflating: birads_classification_training/train/birads_1/10141.png
#   inflating: birads_classification_training/train/birads_1/10142.png
#   inflating: birads_classification_training/train/birads_1/10143.png
#   inflating: birads_classification_training/train/birads_1/10144.png
#   inflating: birads_classification_training/train/birads_1/10145.png
#   inflating: birads_classification_training/train/birads_1/10146.png
#   inflating: birads_classification_training/train/birads_1/10147.png
#   inflating: birads_classification_training/train/birads_1/10148.png
#   inflating: birads_classification_training/train/birads_1/10149.png
#   inflating: birads_classification_training/train/birads_1/10150.png
#   inflating: birads_classification_training/train/birads_1/10151.png
#   inflating: birads_classification_training/train/birads_1/10152.png
#   inflating: birads_classification_training/train/birads_1/10153.png
#   inflating: birads_classification_training/train/birads_1/10154.png
#   inflating: birads_classification_training/train/birads_1/10155.png
#   inflating: birads_classification_training/train/birads_1/10156.png
#   inflating: birads_classification_training/train/birads_1/10157.png
#   inflating: birads_classification_training/train/birads_1/10158.png
#   inflating: birads_classification_training/train/birads_1/10159.png
#   inflating: birads_classification_training/train/birads_1/10160.png
#   inflating: birads_classification_training/train/birads_1/10161.png
#   inflating: birads_classification_training/train/birads_1/10162.png
#   inflating: birads_classification_training/train/birads_1/10163.png
#   inflating: birads_classification_training/train/birads_1/10164.png
#   inflating: birads_classification_training/train/birads_1/10165.png
#   inflating: birads_classification_training/train/birads_1/10166.png
#   inflating: birads_classification_training/train/birads_1/10167.png
#   inflating: birads_classification_training/train/birads_1/10168.png
#   inflating: birads_classification_training/train/birads_1/10169.png
#   inflating: birads_classification_training/train/birads_1/10170.png
#   inflating: birads_classification_training/train/birads_1/10171.png
#   inflating: birads_classification_training/train/birads_1/10172.png
#   inflating: birads_classification_training/train/birads_1/10173.png
#   inflating: birads_classification_training/train/birads_1/10174.png
#   inflating: birads_classification_training/train/birads_1/10175.png
#   inflating: birads_classification_training/train/birads_1/10176.png
#   inflating: birads_classification_training/train/birads_1/10177.png
#   inflating: birads_classification_training/train/birads_1/10178.png
#   inflating: birads_classification_training/train/birads_1/10179.png
#   inflating: birads_classification_training/train/birads_1/10180.png
#   inflating: birads_classification_training/train/birads_1/10181.png
#   inflating: birads_classification_training/train/birads_1/10182.png
#   inflating: birads_classification_training/train/birads_1/10183.png
#   inflating: birads_classification_training/train/birads_1/10184.png
#   inflating: birads_classification_training/train/birads_1/10185.png
#   inflating: birads_classification_training/train/birads_1/10187.png
#   inflating: birads_classification_training/train/birads_1/10188.png
#   inflating: birads_classification_training/train/birads_1/10189.png
#   inflating: birads_classification_training/train/birads_1/10190.png
#   inflating: birads_classification_training/train/birads_1/10191.png
#   inflating: birads_classification_training/train/birads_1/10192.png
#   inflating: birads_classification_training/train/birads_1/10193.png
#   inflating: birads_classification_training/train/birads_1/10194.png
#   inflating: birads_classification_training/train/birads_1/10195.png
#   inflating: birads_classification_training/train/birads_1/10196.png
#   inflating: birads_classification_training/train/birads_1/10197.png
#   inflating: birads_classification_training/train/birads_1/10198.png
#   inflating: birads_classification_training/train/birads_1/10199.png
#   inflating: birads_classification_training/train/birads_1/10200.png
#   inflating: birads_classification_training/train/birads_1/10201.png
#   inflating: birads_classification_training/train/birads_1/10202.png
#   inflating: birads_classification_training/train/birads_1/10203.png
#   inflating: birads_classification_training/train/birads_1/10204.png
#   inflating: birads_classification_training/train/birads_1/10205.png
#   inflating: birads_classification_training/train/birads_1/10206.png
#   inflating: birads_classification_training/train/birads_1/10207.png
#   inflating: birads_classification_training/train/birads_1/10208.png
#   inflating: birads_classification_training/train/birads_1/10209.png
#   inflating: birads_classification_training/train/birads_1/10210.png
#   inflating: birads_classification_training/train/birads_1/10211.png
#   inflating: birads_classification_training/train/birads_1/10212.png
#   inflating: birads_classification_training/train/birads_1/10213.png
#   inflating: birads_classification_training/train/birads_1/10214.png
#   inflating: birads_classification_training/train/birads_1/10215.png
#   inflating: birads_classification_training/train/birads_1/10216.png
#   inflating: birads_classification_training/train/birads_1/10217.png
#   inflating: birads_classification_training/train/birads_1/10218.png
#   inflating: birads_classification_training/train/birads_1/10219.png
#   inflating: birads_classification_training/train/birads_1/10220.png
#   inflating: birads_classification_training/train/birads_1/10221.png
#   inflating: birads_classification_training/train/birads_1/10222.png
#   inflating: birads_classification_training/train/birads_1/10223.png
#   inflating: birads_classification_training/train/birads_1/10224.png
#   inflating: birads_classification_training/train/birads_1/10225.png
#   inflating: birads_classification_training/train/birads_1/10226.png
#   inflating: birads_classification_training/train/birads_1/10227.png
#   inflating: birads_classification_training/train/birads_1/10228.png
#   inflating: birads_classification_training/train/birads_1/10230.png
#   inflating: birads_classification_training/train/birads_1/10231.png
#   inflating: birads_classification_training/train/birads_1/10232.png
#   inflating: birads_classification_training/train/birads_1/10233.png
#   inflating: birads_classification_training/train/birads_1/10234.png
#   inflating: birads_classification_training/train/birads_1/10235.png
#   inflating: birads_classification_training/train/birads_1/10236.png
#   inflating: birads_classification_training/train/birads_1/10237.png
#   inflating: birads_classification_training/train/birads_1/10238.png
#   inflating: birads_classification_training/train/birads_1/10239.png
#   inflating: birads_classification_training/train/birads_1/10240.png
#   inflating: birads_classification_training/train/birads_1/10241.png
#   inflating: birads_classification_training/train/birads_1/10242.png
#   inflating: birads_classification_training/train/birads_1/10243.png
#   inflating: birads_classification_training/train/birads_1/10244.png
#   inflating: birads_classification_training/train/birads_1/10245.png
#   inflating: birads_classification_training/train/birads_1/10246.png
#   inflating: birads_classification_training/train/birads_1/10247.png
#   inflating: birads_classification_training/train/birads_1/10248.png
#   inflating: birads_classification_training/train/birads_1/10249.png
#   inflating: birads_classification_training/train/birads_1/10250.png
#   inflating: birads_classification_training/train/birads_1/10251.png
#   inflating: birads_classification_training/train/birads_1/10252.png
#   inflating: birads_classification_training/train/birads_1/10253.png
#   inflating: birads_classification_training/train/birads_1/10254.png
#   inflating: birads_classification_training/train/birads_1/10255.png
#   inflating: birads_classification_training/train/birads_1/10256.png
#   inflating: birads_classification_training/train/birads_1/10257.png
#   inflating: birads_classification_training/train/birads_1/10258.png
#   inflating: birads_classification_training/train/birads_1/10259.png
#   inflating: birads_classification_training/train/birads_1/10260.png
#   inflating: birads_classification_training/train/birads_1/10261.png
#   inflating: birads_classification_training/train/birads_1/10262.png
#   inflating: birads_classification_training/train/birads_1/10264.png
#   inflating: birads_classification_training/train/birads_1/10265.png
#   inflating: birads_classification_training/train/birads_1/10266.png
#   inflating: birads_classification_training/train/birads_1/10267.png
#   inflating: birads_classification_training/train/birads_1/10268.png
#   inflating: birads_classification_training/train/birads_1/10269.png
#   inflating: birads_classification_training/train/birads_1/10270.png
#   inflating: birads_classification_training/train/birads_1/10271.png
#   inflating: birads_classification_training/train/birads_1/10272.png
#   inflating: birads_classification_training/train/birads_1/10273.png
#   inflating: birads_classification_training/train/birads_1/10274.png
#   inflating: birads_classification_training/train/birads_1/10275.png
#   inflating: birads_classification_training/train/birads_1/10276.png
#   inflating: birads_classification_training/train/birads_1/10278.png
#   inflating: birads_classification_training/train/birads_1/10279.png
#   inflating: birads_classification_training/train/birads_1/10280.png
#   inflating: birads_classification_training/train/birads_1/10281.png
#   inflating: birads_classification_training/train/birads_1/10282.png
#   inflating: birads_classification_training/train/birads_1/10283.png
#   inflating: birads_classification_training/train/birads_1/10284.png
#   inflating: birads_classification_training/train/birads_1/10285.png
#   inflating: birads_classification_training/train/birads_1/10286.png
#   inflating: birads_classification_training/train/birads_1/10287.png
#   inflating: birads_classification_training/train/birads_1/10288.png
#   inflating: birads_classification_training/train/birads_1/10289.png
#   inflating: birads_classification_training/train/birads_1/10290.png
#   inflating: birads_classification_training/train/birads_1/10291.png
#   inflating: birads_classification_training/train/birads_1/10292.png
#   inflating: birads_classification_training/train/birads_1/10293.png
#   inflating: birads_classification_training/train/birads_1/10294.png
#   inflating: birads_classification_training/train/birads_1/10295.png
#   inflating: birads_classification_training/train/birads_1/10296.png
#   inflating: birads_classification_training/train/birads_1/10297.png
#   inflating: birads_classification_training/train/birads_1/10298.png
#   inflating: birads_classification_training/train/birads_1/10299.png
#   inflating: birads_classification_training/train/birads_1/10300.png
#   inflating: birads_classification_training/train/birads_1/10301.png
#   inflating: birads_classification_training/train/birads_1/10302.png
#   inflating: birads_classification_training/train/birads_1/10303.png
#   inflating: birads_classification_training/train/birads_1/10304.png
#   inflating: birads_classification_training/train/birads_1/10305.png
#   inflating: birads_classification_training/train/birads_1/10307.png
#   inflating: birads_classification_training/train/birads_1/10308.png
#   inflating: birads_classification_training/train/birads_1/10309.png
#   inflating: birads_classification_training/train/birads_1/10310.png
#   inflating: birads_classification_training/train/birads_1/10311.png
#   inflating: birads_classification_training/train/birads_1/10312.png
#   inflating: birads_classification_training/train/birads_1/10313.png
#   inflating: birads_classification_training/train/birads_1/10314.png
#   inflating: birads_classification_training/train/birads_1/10315.png
#   inflating: birads_classification_training/train/birads_1/10316.png
#   inflating: birads_classification_training/train/birads_1/10317.png
#   inflating: birads_classification_training/train/birads_1/10318.png
#   inflating: birads_classification_training/train/birads_1/10319.png
#   inflating: birads_classification_training/train/birads_1/10320.png
#   inflating: birads_classification_training/train/birads_1/10321.png
#   inflating: birads_classification_training/train/birads_1/10322.png
#   inflating: birads_classification_training/train/birads_1/10323.png
#   inflating: birads_classification_training/train/birads_1/10324.png
#   inflating: birads_classification_training/train/birads_1/10325.png
#   inflating: birads_classification_training/train/birads_1/10326.png
#   inflating: birads_classification_training/train/birads_1/10327.png
#   inflating: birads_classification_training/train/birads_1/10329.png
#   inflating: birads_classification_training/train/birads_1/10330.png
#   inflating: birads_classification_training/train/birads_1/10331.png
#   inflating: birads_classification_training/train/birads_1/10332.png
#   inflating: birads_classification_training/train/birads_1/10333.png
#   inflating: birads_classification_training/train/birads_1/10334.png
#   inflating: birads_classification_training/train/birads_1/10335.png
#   inflating: birads_classification_training/train/birads_1/10336.png
#   inflating: birads_classification_training/train/birads_1/10337.png
#   inflating: birads_classification_training/train/birads_1/10338.png
#   inflating: birads_classification_training/train/birads_1/10339.png
#   inflating: birads_classification_training/train/birads_1/10340.png
#   inflating: birads_classification_training/train/birads_1/10341.png
#   inflating: birads_classification_training/train/birads_1/10342.png
#   inflating: birads_classification_training/train/birads_1/10343.png
#   inflating: birads_classification_training/train/birads_1/10344.png
#   inflating: birads_classification_training/train/birads_1/10345.png
#   inflating: birads_classification_training/train/birads_1/10346.png
#   inflating: birads_classification_training/train/birads_1/10347.png
#   inflating: birads_classification_training/train/birads_1/10348.png
#   inflating: birads_classification_training/train/birads_1/10349.png
#   inflating: birads_classification_training/train/birads_1/10350.png
#   inflating: birads_classification_training/train/birads_1/10351.png
#   inflating: birads_classification_training/train/birads_1/10352.png
#   inflating: birads_classification_training/train/birads_1/10353.png
#   inflating: birads_classification_training/train/birads_1/10354.png
#   inflating: birads_classification_training/train/birads_1/10355.png
#   inflating: birads_classification_training/train/birads_1/10356.png
#   inflating: birads_classification_training/train/birads_1/10357.png
#   inflating: birads_classification_training/train/birads_1/10358.png
#   inflating: birads_classification_training/train/birads_1/10359.png
#   inflating: birads_classification_training/train/birads_1/10360.png
#   inflating: birads_classification_training/train/birads_1/10361.png
#   inflating: birads_classification_training/train/birads_1/10362.png
#   inflating: birads_classification_training/train/birads_1/10363.png
#   inflating: birads_classification_training/train/birads_1/10364.png
#   inflating: birads_classification_training/train/birads_1/10365.png
#   inflating: birads_classification_training/train/birads_1/10366.png
#   inflating: birads_classification_training/train/birads_1/10367.png
#   inflating: birads_classification_training/train/birads_1/10368.png
#   inflating: birads_classification_training/train/birads_1/10369.png
#   inflating: birads_classification_training/train/birads_1/10370.png
#   inflating: birads_classification_training/train/birads_1/10371.png
#   inflating: birads_classification_training/train/birads_1/10372.png
#   inflating: birads_classification_training/train/birads_1/10373.png
#   inflating: birads_classification_training/train/birads_1/10374.png
#   inflating: birads_classification_training/train/birads_1/10375.png
#   inflating: birads_classification_training/train/birads_1/10376.png
#   inflating: birads_classification_training/train/birads_1/10377.png
#   inflating: birads_classification_training/train/birads_1/10378.png
#   inflating: birads_classification_training/train/birads_1/10379.png
#   inflating: birads_classification_training/train/birads_1/10380.png
#   inflating: birads_classification_training/train/birads_1/10382.png
#   inflating: birads_classification_training/train/birads_1/10383.png
#   inflating: birads_classification_training/train/birads_1/10384.png
#   inflating: birads_classification_training/train/birads_1/10385.png
#   inflating: birads_classification_training/train/birads_1/10386.png
#   inflating: birads_classification_training/train/birads_1/10387.png
#   inflating: birads_classification_training/train/birads_1/10388.png
#   inflating: birads_classification_training/train/birads_1/10389.png
#   inflating: birads_classification_training/train/birads_1/10390.png
#   inflating: birads_classification_training/train/birads_1/10391.png
#   inflating: birads_classification_training/train/birads_1/10392.png
#   inflating: birads_classification_training/train/birads_1/10393.png
#   inflating: birads_classification_training/train/birads_1/10394.png
#   inflating: birads_classification_training/train/birads_1/10395.png
#   inflating: birads_classification_training/train/birads_1/10396.png
#   inflating: birads_classification_training/train/birads_1/10397.png
#   inflating: birads_classification_training/train/birads_1/10398.png
#   inflating: birads_classification_training/train/birads_1/10399.png
#   inflating: birads_classification_training/train/birads_1/10400.png
#   inflating: birads_classification_training/train/birads_1/10401.png
#   inflating: birads_classification_training/train/birads_1/10402.png
#   inflating: birads_classification_training/train/birads_1/10404.png
#   inflating: birads_classification_training/train/birads_1/10405.png
#   inflating: birads_classification_training/train/birads_1/10406.png
#   inflating: birads_classification_training/train/birads_1/10408.png
#   inflating: birads_classification_training/train/birads_1/10409.png
#   inflating: birads_classification_training/train/birads_1/10410.png
#   inflating: birads_classification_training/train/birads_1/10411.png
#   inflating: birads_classification_training/train/birads_1/10412.png
#   inflating: birads_classification_training/train/birads_1/10413.png
#   inflating: birads_classification_training/train/birads_1/10414.png
#   inflating: birads_classification_training/train/birads_1/10415.png
#   inflating: birads_classification_training/train/birads_1/10416.png
#   inflating: birads_classification_training/train/birads_1/10417.png
#   inflating: birads_classification_training/train/birads_1/10418.png
#   inflating: birads_classification_training/train/birads_1/10419.png
#   inflating: birads_classification_training/train/birads_1/10420.png
# ...
#   inflating: birads_classification_training/val/birads_1/10858.png
#   inflating: birads_classification_training/val/birads_1/10859.png
#   inflating: birads_classification_training/val/birads_1/10860.png
#   inflating: birads_classification_training/val/birads_1/10861.png
#   inflating: birads_classification_training/val/birads_1/10862.png
#   inflating: birads_classification_training/val/birads_1/10863.png
#   inflating: birads_classification_training/val/birads_1/10864.png
#   inflating: birads_classification_training/val/birads_1/10865.png
#   inflating: birads_classification_training/val/birads_1/10866.png
#   inflating: birads_classification_training/val/birads_1/10867.png
#   inflating: birads_classification_training/val/birads_1/10868.png
#   inflating: birads_classification_training/val/birads_1/10869.png
#   inflating: birads_classification_training/val/birads_1/10870.png
#   inflating: birads_classification_training/val/birads_1/10871.png
#   inflating: birads_classification_training/val/birads_1/10872.png
#   inflating: birads_classification_training/val/birads_1/10873.png
#   inflating: birads_classification_training/val/birads_1/10874.png
#   inflating: birads_classification_training/val/birads_1/10875.png
#   inflating: birads_classification_training/val/birads_1/10876.png
#   inflating: birads_classification_training/val/birads_1/10877.png
#   inflating: birads_classification_training/val/birads_1/10878.png
#   inflating: birads_classification_training/val/birads_1/10879.png
#   inflating: birads_classification_training/val/birads_1/10880.png
#   inflating: birads_classification_training/val/birads_1/10881.png
#   inflating: birads_classification_training/val/birads_1/10882.png
#   inflating: birads_classification_training/val/birads_1/10883.png
#   inflating: birads_classification_training/val/birads_1/10884.png
#   inflating: birads_classification_training/val/birads_1/10885.png
#   inflating: birads_classification_training/val/birads_1/10886.png
#   inflating: birads_classification_training/val/birads_1/10887.png
#   inflating: birads_classification_training/val/birads_1/10888.png
#   inflating: birads_classification_training/val/birads_1/10889.png
#   inflating: birads_classification_training/val/birads_1/10890.png
#   inflating: birads_classification_training/val/birads_1/10891.png
#   inflating: birads_classification_training/val/birads_1/10892.png
#   inflating: birads_classification_training/val/birads_1/10893.png
#   inflating: birads_classification_training/val/birads_1/10894.png
#   inflating: birads_classification_training/val/birads_1/10895.png
#   inflating: birads_classification_training/val/birads_1/10896.png
#   inflating: birads_classification_training/val/birads_1/10897.png
#   inflating: birads_classification_training/val/birads_1/10898.png
#   inflating: birads_classification_training/val/birads_1/10899.png
#   inflating: birads_classification_training/val/birads_1/10900.png
#   inflating: birads_classification_training/val/birads_1/10901.png
#   inflating: birads_classification_training/val/birads_1/10902.png
#   inflating: birads_classification_training/val/birads_1/10903.png
#   inflating: birads_classification_training/val/birads_1/10904.png
#   inflating: birads_classification_training/val/birads_1/10905.png
#   inflating: birads_classification_training/val/birads_1/10906.png
#   inflating: birads_classification_training/val/birads_1/10907.png
#   inflating: birads_classification_training/val/birads_1/10908.png
#   inflating: birads_classification_training/val/birads_1/10909.png
#   inflating: birads_classification_training/val/birads_1/10910.png
#   inflating: birads_classification_training/val/birads_1/10911.png
#   inflating: birads_classification_training/val/birads_1/10912.png
#   inflating: birads_classification_training/val/birads_1/10913.png
#   inflating: birads_classification_training/val/birads_1/10914.png
#   inflating: birads_classification_training/val/birads_1/10915.png
#   inflating: birads_classification_training/val/birads_1/10916.png
#   inflating: birads_classification_training/val/birads_1/10917.png
#   inflating: birads_classification_training/val/birads_1/10918.png
#   inflating: birads_classification_training/val/birads_1/10919.png
#   inflating: birads_classification_training/val/birads_1/10920.png
#   inflating: birads_classification_training/val/birads_1/10921.png
#    creating: birads_classification_training/val/birads_2/
#   inflating: birads_classification_training/val/birads_2/11513.png
#   inflating: birads_classification_training/val/birads_2/11514.png
#   inflating: birads_classification_training/val/birads_2/11515.png
#   inflating: birads_classification_training/val/birads_2/11516.png
#   inflating: birads_classification_training/val/birads_2/11517.png
#   inflating: birads_classification_training/val/birads_2/11518.png
#   inflating: birads_classification_training/val/birads_2/11519.png
#   inflating: birads_classification_training/val/birads_2/11520.png
#   inflating: birads_classification_training/val/birads_2/11521.png
#   inflating: birads_classification_training/val/birads_2/11522.png
#   inflating: birads_classification_training/val/birads_2/11523.png
#   inflating: birads_classification_training/val/birads_2/11524.png
#   inflating: birads_classification_training/val/birads_2/11525.png
#   inflating: birads_classification_training/val/birads_2/11526.png
#   inflating: birads_classification_training/val/birads_2/11527.png
#   inflating: birads_classification_training/val/birads_2/11529.png
#   inflating: birads_classification_training/val/birads_2/11530.png
#   inflating: birads_classification_training/val/birads_2/11531.png
#   inflating: birads_classification_training/val/birads_2/11532.png
#   inflating: birads_classification_training/val/birads_2/11534.png
#   inflating: birads_classification_training/val/birads_2/11535.png
#   inflating: birads_classification_training/val/birads_2/11536.png
#   inflating: birads_classification_training/val/birads_2/11537.png
#   inflating: birads_classification_training/val/birads_2/11538.png
#   inflating: birads_classification_training/val/birads_2/11539.png
#   inflating: birads_classification_training/val/birads_2/11540.png
#   inflating: birads_classification_training/val/birads_2/11541.png
#   inflating: birads_classification_training/val/birads_2/11542.png
#   inflating: birads_classification_training/val/birads_2/11543.png
#   inflating: birads_classification_training/val/birads_2/11544.png
#   inflating: birads_classification_training/val/birads_2/11545.png
#   inflating: birads_classification_training/val/birads_2/11546.png
#   inflating: birads_classification_training/val/birads_2/11547.png
#   inflating: birads_classification_training/val/birads_2/11548.png
#   inflating: birads_classification_training/val/birads_2/11549.png
#   inflating: birads_classification_training/val/birads_2/11550.png
#   inflating: birads_classification_training/val/birads_2/11551.png
#   inflating: birads_classification_training/val/birads_2/11552.png
#   inflating: birads_classification_training/val/birads_2/11553.png
#   inflating: birads_classification_training/val/birads_2/11554.png
#   inflating: birads_classification_training/val/birads_2/11555.png
#   inflating: birads_classification_training/val/birads_2/11556.png
#   inflating: birads_classification_training/val/birads_2/11558.png
#   inflating: birads_classification_training/val/birads_2/11559.png
#   inflating: birads_classification_training/val/birads_2/11560.png
#   inflating: birads_classification_training/val/birads_2/11561.png
#   inflating: birads_classification_training/val/birads_2/11563.png
#   inflating: birads_classification_training/val/birads_2/11564.png
#   inflating: birads_classification_training/val/birads_2/11565.png
#   inflating: birads_classification_training/val/birads_2/11566.png
#   inflating: birads_classification_training/val/birads_2/11567.png
#   inflating: birads_classification_training/val/birads_2/11568.png
#   inflating: birads_classification_training/val/birads_2/11569.png
#   inflating: birads_classification_training/val/birads_2/11570.png
#   inflating: birads_classification_training/val/birads_2/11571.png
#   inflating: birads_classification_training/val/birads_2/11572.png
#   inflating: birads_classification_training/val/birads_2/11573.png
#   inflating: birads_classification_training/val/birads_2/11574.png
#   inflating: birads_classification_training/val/birads_2/11575.png
#    creating: birads_classification_training/val/birads_4/
#   inflating: birads_classification_training/val/birads_4/12061.png
#   inflating: birads_classification_training/val/birads_4/12062.png
#   inflating: birads_classification_training/val/birads_4/12063.png
#   inflating: birads_classification_training/val/birads_4/12064.png
#   inflating: birads_classification_training/val/birads_4/12065.png
#   inflating: birads_classification_training/val/birads_4/12066.png
#   inflating: birads_classification_training/val/birads_4/12067.png
#   inflating: birads_classification_training/val/birads_4/12068.png
#   inflating: birads_classification_training/val/birads_4/12069.png
#   inflating: birads_classification_training/val/birads_4/12070.png
#   inflating: birads_classification_training/val/birads_4/12071.png
#   inflating: birads_classification_training/val/birads_4/12072.png
#   inflating: birads_classification_training/val/birads_4/12073.png
#   inflating: birads_classification_training/val/birads_4/12074.png
#   inflating: birads_classification_training/val/birads_4/12075.png
#   inflating: birads_classification_training/val/birads_4/12076.png
#   inflating: birads_classification_training/val/birads_4/12077.png
#   inflating: birads_classification_training/val/birads_4/12078.png
#   inflating: birads_classification_training/val/birads_4/12079.png
#   inflating: birads_classification_training/val/birads_4/12080.png
#   inflating: birads_classification_training/val/birads_4/12081.png
#   inflating: birads_classification_training/val/birads_4/12082.png
#   inflating: birads_classification_training/val/birads_4/12083.png
#   inflating: birads_classification_training/val/birads_4/12084.png
#   inflating: birads_classification_training/val/birads_4/12085.png
#   inflating: birads_classification_training/val/birads_4/12086.png
#   inflating: birads_classification_training/val/birads_4/12087.png
#   inflating: birads_classification_training/val/birads_4/12088.png
#   inflating: birads_classification_training/val/birads_4/12089.png
#   inflating: birads_classification_training/val/birads_4/12090.png
#   inflating: birads_classification_training/val/birads_4/12091.png
#   inflating: birads_classification_training/val/birads_4/12092.png
#   inflating: birads_classification_training/val/birads_4/12093.png
#   inflating: birads_classification_training/val/birads_4/12094.png
#   inflating: birads_classification_training/val/birads_4/12095.png
#   inflating: birads_classification_training/val/birads_4/12096.png
#   inflating: birads_classification_training/val/birads_4/12097.png
#   inflating: birads_classification_training/val/birads_4/12098.png
#   inflating: birads_classification_training/val/birads_4/12099.png
#   inflating: birads_classification_training/val/birads_4/12100.png
#   inflating: birads_classification_training/val/birads_4/12101.png
#   inflating: birads_classification_training/val/birads_4/12102.png
#   inflating: birads_classification_training/val/birads_4/12103.png
#   inflating: birads_classification_training/val/birads_4/12104.png
#   inflating: birads_classification_training/val/birads_4/12105.png
#   inflating: birads_classification_training/val/birads_4/12106.png
#   inflating: birads_classification_training/val/birads_4/12107.png
#   inflating: birads_classification_training/val/birads_4/12108.png
#   inflating: birads_classification_training/val/birads_4/12109.png
#   inflating: birads_classification_training/val/birads_4/12110.png
#   inflating: birads_classification_training/val/birads_4/12111.png
#   inflating: birads_classification_training/val/birads_4/12112.png
#    creating: birads_classification_training/val/birads_5/
#   inflating: birads_classification_training/val/birads_5/12613.png
#   inflating: birads_classification_training/val/birads_5/12614.png
#   inflating: birads_classification_training/val/birads_5/12615.png
#   inflating: birads_classification_training/val/birads_5/12616.png
#   inflating: birads_classification_training/val/birads_5/12617.png
#   inflating: birads_classification_training/val/birads_5/12618.png
#   inflating: birads_classification_training/val/birads_5/12619.png
#   inflating: birads_classification_training/val/birads_5/12620.png
#   inflating: birads_classification_training/val/birads_5/12621.png
#   inflating: birads_classification_training/val/birads_5/12622.png
#   inflating: birads_classification_training/val/birads_5/12623.png
#   inflating: birads_classification_training/val/birads_5/12624.png
#   inflating: birads_classification_training/val/birads_5/12625.png
#   inflating: birads_classification_training/val/birads_5/12626.png
#   inflating: birads_classification_training/val/birads_5/12627.png
#   inflating: birads_classification_training/val/birads_5/12628.png
#   inflating: birads_classification_training/val/birads_5/12629.png
#   inflating: birads_classification_training/val/birads_5/12630.png
#   inflating: birads_classification_training/val/birads_5/12631.png
#   inflating: birads_classification_training/val/birads_5/12632.png
#   inflating: birads_classification_training/val/birads_5/12633.png
#   inflating: birads_classification_training/val/birads_5/12634.png
#   inflating: birads_classification_training/val/birads_5/12635.png
#   inflating: birads_classification_training/val/birads_5/12636.png
#   inflating: birads_classification_training/val/birads_5/12637.png
#   inflating: birads_classification_training/val/birads_5/12638.png
#   inflating: birads_classification_training/val/birads_5/12639.png
#   inflating: birads_classification_training/val/birads_5/12640.png
#   inflating: birads_classification_training/val/birads_5/12641.png
#   inflating: birads_classification_training/val/birads_5/12642.png
#   inflating: birads_classification_training/val/birads_5/12643.png
#   inflating: birads_classification_training/val/birads_5/12644.png
#   inflating: birads_classification_training/val/birads_5/12645.png
#   inflating: birads_classification_training/val/birads_5/12646.png
#   inflating: birads_classification_training/val/birads_5/12648.png
#   inflating: birads_classification_training/val/birads_5/12649.png
#   inflating: birads_classification_training/val/birads_5/12650.png
#   inflating: birads_classification_training/val/birads_5/12651.png
#   inflating: birads_classification_training/val/birads_5/12652.png
#   inflating: birads_classification_training/val/birads_5/12653.png
#   inflating: birads_classification_training/val/birads_5/12654.png
#   inflating: birads_classification_training/val/birads_5/12655.png
#   inflating: birads_classification_training/val/birads_5/12656.png
#   inflating: birads_classification_training/val/birads_5/12657.png
#   inflating: birads_classification_training/val/birads_5/12658.png
#   inflating: birads_classification_training/val/birads_5/12659.png
#   inflating: birads_classification_training/val/birads_5/12660.png
#   inflating: birads_classification_training/val/birads_5/12661.png
#   inflating: birads_classification_training/val/birads_5/12662.png
#   inflating: birads_classification_training/val/birads_5/12663.png
#   inflating: birads_classification_training/val/birads_5/12664.png
#   inflating: birads_classification_training/val/birads_5/12665.png
#   inflating: birads_classification_training/val/birads_5/12666.png
#   inflating: birads_classification_training/val/birads_5/12667.png

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm
import copy
from sklearn.preprocessing import LabelEncoder

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models

if torch.cuda.is_available():
    print('CUDA is available. Working on GPU')
    DEVICE = torch.device('cuda')
else:
    print('CUDA is not available. Working on CPU')
    DEVICE = torch.device('cpu')
# Out:
# CUDA is not available. Working on CPU

# %%
from glob import glob
DIR_MAIN = "/content/birads_classification_training/"
DIR_TRAIN = DIR_MAIN + 'train/'
DIR_VAL = DIR_MAIN + 'val/'
DIR_TEST = DIR_MAIN + 'test/'

# Number of labels - 200
labels = os.listdir(DIR_TRAIN)

# Initialize labels encoder
encoder_labels = LabelEncoder()
encoder_labels.fit(labels)

# Create lists of files and labels for training (100'000 items)
files_train = []
labels_train = []
for label in labels:
    for filename in os.listdir(DIR_TRAIN + label):
        files_train.append(DIR_TRAIN + label + filename)
        labels_train.append(label)

# Create lists of files and labels for validation (10'000 items)
files_val = []
labels_val = []
for filename in os.listdir(DIR_VAL):
    files_val.append(DIR_VAL + filename)

val_df = glob("/content/birads_classification_training/val/*.png")
for f in files_val:
    l = val_df.loc[val_df['File'] == f[len(DIR_VAL):]]['Label'].values[0]
    labels_val.append(l)

# List of files for testing (10'000 items)
files_test = []
for filename in os.listdir(DIR_TEST):
    files_test.append(DIR_TEST + filename)
    files_test = sorted(files_test)

print("The first five files from the list of train images:", files_train[:5])
print("\nThe first five labels from the list of train labels:", labels_train[:5])
print("\nThe first five files from the list of validation images:", files_val[:5])
print("\nThe first five labels from the list of validation labels:", labels_val[:5])
print("\nThe first five files from the list of test images:", files_test[:5])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-4c7c0552d597> in <cell line: 29>()
#      28 val_df = glob("/content/birads_classification_training/val/*.png")
#      29 for f in files_val:
# ---> 30     l = val_df.loc[val_df['File'] == f[len(DIR_VAL):]]['Label'].values[0]
#      31     labels_val.append(l)
#      32
#
# AttributeError: 'list' object has no attribute 'loc'

# %%
class ImagesDataset(Dataset):
    def __init__(self, files, labels, encoder, transforms, mode):
        super().__init__()
        self.files = files
        self.labels = labels
        self.encoder = encoder
        self.transforms = transforms
        self.mode = mode

    def __len__(self):
        return len(self.files)

    def __getitem__(self, index):
        pic = Image.open(self.files[index]).convert('RGB')

        if self.mode == 'train' or self.mode == 'val':
            x = self.transforms(pic)
            label = self.labels[index]
            y = self.encoder.transform([label])[0]
            return x, y
        elif self.mode == 'test':
            x = self.transforms(pic)
            return x, self.files[index]

transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.4802, 0.4481, 0.3975], [0.2302, 0.2265, 0.2262]),
    transforms.RandomErasing(p=0.5, scale=(0.06, 0.08), ratio=(1, 3), value=0, inplace=True)
])

transforms_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.4802, 0.4481, 0.3975], [0.2302, 0.2265, 0.2262])
])

# %%
train_dataset = ImagesDataset(files=files_train,
                              labels=labels_train,
                              encoder=encoder_labels,
                              transforms=transforms_train,
                              mode='train')

val_dataset = ImagesDataset(files=files_val,
                            labels=labels_val,
                            encoder=encoder_labels,
                            transforms=transforms_val,
                            mode='val')

test_dataset = ImagesDataset(files=files_test,
                             labels=None,
                             encoder=None,
                             transforms=transforms_val,
                             mode='test')

fig, axs = plt.subplots(3, 6, figsize=(20,11))
fig.suptitle('Random pictures from train dataset', fontsize=20)
for ax in axs.flatten():
    n = np.random.randint(len(train_dataset))
    img = train_dataset[n][0]
    img = img.numpy().transpose((1, 2, 0))
    mean = np.array([0.4802, 0.4481, 0.3975])
    std = np.array([0.2302, 0.2265, 0.2262])
    img = std * img + mean
    img = np.clip(img, 0, 1)
    ax.set_title(encoder_labels.inverse_transform([train_dataset[n][1]])[0])
    ax.imshow(img)

# %%
def training(model, model_name, num_epochs, train_dataloader, val_dataloader):

    loss_function = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0003)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.33)

    train_loss_array = []
    train_acc_array = []
    val_loss_array = []
    val_acc_array = []
    lowest_val_loss = np.inf
    best_model = None

    for epoch in tqdm(range(num_epochs)):

        print('Epoch: {} | Learning rate: {}'.format(epoch + 1, scheduler.get_lr()))

        for phase in ['train', 'val']:

            epoch_loss = 0
            epoch_correct_items = 0
            epoch_items = 0

            if phase == 'train':
                model.train()
                with torch.enable_grad():
                    for samples, targets in train_dataloader:
                        samples = samples.to(DEVICE)
                        targets = targets.to(DEVICE)

                        optimizer.zero_grad()
                        outputs = model(samples)
                        loss = loss_function(outputs, targets)
                        preds = outputs.argmax(dim=1)
                        correct_items = (preds == targets).float().sum()

                        loss.backward()
                        optimizer.step()

                        epoch_loss += loss.item()
                        epoch_correct_items += correct_items.item()
                        epoch_items += len(targets)

                train_loss_array.append(epoch_loss / epoch_items)
                train_acc_array.append(epoch_correct_items / epoch_items)

                scheduler.step()

            elif phase == 'val':
                model.eval()
                with torch.no_grad():
                    for samples, targets in val_dataloader:
                        samples = samples.to(DEVICE)
                        targets = targets.to(DEVICE)

                        outputs = model(samples)
                        loss = loss_function(outputs, targets)
                        preds = outputs.argmax(dim=1)
                        correct_items = (preds == targets).float().sum()

                        epoch_loss += loss.item()
                        epoch_correct_items += correct_items.item()
                        epoch_items += len(targets)

                val_loss_array.append(epoch_loss / epoch_items)
                val_acc_array.append(epoch_correct_items / epoch_items)

                if epoch_loss / epoch_items < lowest_val_loss:
                    lowest_val_loss = epoch_loss / epoch_items
                    torch.save(model.state_dict(), '{}_weights.pth'.format(model_name))
                    best_model = copy.deepcopy(model)
                    print("\t| New lowest val loss for {}: {}".format(model_name, lowest_val_loss))

    return best_model, train_loss_array, train_acc_array, val_loss_array, val_acc_array


def visualize_training_results(train_loss_array,
                               val_loss_array,
                               train_acc_array,
                               val_acc_array,
                               num_epochs,
                               model_name,
                               batch_size):
    fig, axs = plt.subplots(1, 2, figsize=(14,4))
    fig.suptitle("{} training | Batch size: {}".format(model_name, batch_size), fontsize = 16)
    axs[0].plot(list(range(1, num_epochs+1)), train_loss_array, label="train_loss")
    axs[0].plot(list(range(1, num_epochs+1)), val_loss_array, label="val_loss")
    axs[0].legend(loc='best')
    axs[0].set(xlabel='epochs', ylabel='loss')
    axs[1].plot(list(range(1, num_epochs+1)), train_acc_array, label="train_acc")
    axs[1].plot(list(range(1, num_epochs+1)), val_acc_array, label="val_acc")
    axs[1].legend(loc='best')
    axs[1].set(xlabel='epochs', ylabel='accuracy')
    plt.show();

# %%
train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=False)
num_epochs = 200

# %%
class EnsembleModel(nn.Module):
    def __init__(self, modelA, modelB, modelC):
        super().__init__()
        self.modelA = modelA
        self.modelB = modelB
        self.modelC = modelC
        self.classifier = nn.Linear(200 * 3, 200)

    def forward(self, x):
        x1 = self.modelA(x)
        x2 = self.modelB(x)
        x3 = self.modelC(x)
        x = torch.cat((x1, x2, x3), dim=1)
        out = self.classifier(x)
        return out

ensemble_model = EnsembleModel(model_densenet161, model_resnet152, model_vgg19_bn)

for param in ensemble_model.parameters():
    param.requires_grad = False

for param in ensemble_model.classifier.parameters():
    param.requires_grad = True

ensemble_model = ensemble_model.to(DEVICE)

# %%
ensemble_training_results = training(model=ensemble_model,
                                     model_name='Ensemble',
                                     num_epochs=200,
                                     train_dataloader=train_dataloader,
                                     val_dataloader=val_dataloader)

ensemble_model, train_loss_array, train_acc_array, val_loss_array, val_acc_array = ensemble_training_results

min_loss = min(val_loss_array)
min_loss_iteration = val_loss_array.index(min_loss)
min_loss_accuracy = val_acc_array[min_loss_iteration]

visualize_training_results(train_loss_array,
                           val_loss_array,
                           train_acc_array,
                           val_acc_array,
                           num_epochs=20,
                           model_name="Ensemble model",
                           batch_size=64)
print("\nTraining results:")
print("\tMin val loss {:.4f} was achieved during iteration #{}".format(min_loss, min_loss_iteration + 1))
print("\tVal accuracy during min val loss is {:.4f}".format(min_loss_accuracy))
